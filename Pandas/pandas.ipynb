# %%
import pandas as pd

# %%
data = pd.read_csv('E:/work/ML_prac/Data/sc_cust_info_txn_v1.5.csv')
print(data.head(3))
# Out:
#    base_ym  dpro_tgt_perd_val  cust_ctg_type cust_class sex_type age  \
# 0   202006           20200630          10001          C        F  28
# 1   202006           20200630          10001          _        _   _
# 2   202006           20200630          10001          E        F  24
#
#    efct_svc_count dt_stop_yn npay_yn  r3m_avg_bill_amt  r3m_A_avg_arpu_amt  \
# 0               0          N       N            2640.0               792.0
# 1               1          N       N             300.0                90.0
# 2               1          N       N           16840.0              2526.0
#
#    r3m_B_avg_arpu_amt  r6m_A_avg_arpu_amt  r6m_B_avg_arpu_amt termination_yn
# 0              1584.0                 0.0                 0.0              Y
# 1               180.0                 0.0                 0.0              Y
# 2              6983.0                 0.0              6981.0              N

# %%
data.shape
# Out:
# (9930, 15)

# %%
data.columns
# Out:
# Index(['base_ym', 'dpro_tgt_perd_val', 'cust_ctg_type', 'cust_class',
#        'sex_type', 'age', 'efct_svc_count', 'dt_stop_yn', 'npay_yn',
#        'r3m_avg_bill_amt', 'r3m_A_avg_arpu_amt', 'r3m_B_avg_arpu_amt',
#        'r6m_A_avg_arpu_amt', 'r6m_B_avg_arpu_amt', 'termination_yn'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.describe()
# Out:
#         base_ym  dpro_tgt_perd_val  cust_ctg_type  efct_svc_count  \
# count    9930.0             9930.0    9930.000000     9930.000000
# mean   202006.0         20200630.0   10001.372810        1.520040
# std         0.0                0.0       1.605016       15.404037
# min    202006.0         20200630.0   10001.000000        0.000000
# 25%    202006.0         20200630.0   10001.000000        1.000000
# 50%    202006.0         20200630.0   10001.000000        1.000000
# 75%    202006.0         20200630.0   10001.000000        1.000000
# max    202006.0         20200630.0   10010.000000      905.000000
#
#        r3m_avg_bill_amt  r3m_A_avg_arpu_amt  r3m_B_avg_arpu_amt  \
# count      9.930000e+03        9.930000e+03        9.930000e+03
# mean       1.181774e+04        1.897536e+03        6.395259e+03
# std        1.397822e+05        1.235342e+04        8.346138e+04
# min        0.000000e+00        0.000000e+00        0.000000e+00
# ...

# %%
data[['cust_class', 'age', 'r3m_avg_bill_amt']]
# Out:
#      cust_class age  r3m_avg_bill_amt
# 0             C  28         2640.0000
# 1             _   _          300.0000
# 2             E  24        16840.0000
# 3             F  32        15544.7334
# 4             D  18         4700.0000
# ...         ...  ..               ...
# 9925          C  15         1296.0999
# 9926          G  12        13799.6666
# 9927          C   _         1396.2000
# 9928          C  40         3140.0000
# 9929          C  59         2436.9000
#
# [9930 rows x 3 columns]

# %%
data.loc[[0,3,6],['Survived','Pclass','Name']]
# Out:
#    Survived  Pclass                                          Name
# 0         0       3                       Braund, Mr. Owen Harris
# 3         1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 6         0       1                       McCarthy, Mr. Timothy J

# %%
data.iloc[[0,3,6],[0,2]]
# Out:
#    PassengerId  Pclass
# 0            1       3
# 3            4       1
# 6            7       1

# %%
extract = data[(data['sex_type']=='M') 
               & (data['r3m_avg_bill_amt']>=50000) 
               & (data['r3m_avg_bill_amt']< 100000)]
extract.head()
# Out:
#       base_ym  dpro_tgt_perd_val  cust_ctg_type cust_class sex_type age  \
# 372    202006           20200630          10001          F        M  28
# 1049   202006           20200630          10001          D        M  20
# 1364   202006           20200630          10001          _        M  45
# 1793   202006           20200630          10001          G        M  48
# 2027   202006           20200630          10001          G        M  47
#
#       efct_svc_count dt_stop_yn npay_yn  r3m_avg_bill_amt  r3m_A_avg_arpu_amt  \
# 372                1          N       N       65113.66670           1310.4000
# 1049               2          N       N       80335.67685          69136.1001
# 1364               1          N       Y       54865.70000           2321.8666
# 1793               1          N       N       64804.34037          47599.4501
# 2027               1          N       Y       55368.98422          37432.2666
#
# ...

# %%
data['r3m_avg_bill_amt2'] = data['r3m_avg_bill_amt'] * 2
data.head()
# Out:
#    base_ym  dpro_tgt_perd_val  cust_ctg_type cust_class sex_type age  \
# 0   202006           20200630          10001          C        F  28
# 1   202006           20200630          10001          _        _   _
# 2   202006           20200630          10001          E        F  24
# 3   202006           20200630          10001          F        F  32
# 4   202006           20200630          10001          D        M  18
#
#    efct_svc_count dt_stop_yn npay_yn  r3m_avg_bill_amt  r3m_A_avg_arpu_amt  \
# 0               0          N       N         2640.0000           792.00000
# 1               1          N       N          300.0000            90.00000
# 2               1          N       N        16840.0000          2526.00000
# 3               1          N       N        15544.7334          2331.71001
# 4               1          N       N         4700.0000             0.00000
#
#    r3m_B_avg_arpu_amt  r6m_A_avg_arpu_amt  r6m_B_avg_arpu_amt termination_yn  \
# ...

# %%
data[['r3m_avg_bill_amt2','r3m_avg_bill_amt']]
# Out:
#       r3m_avg_bill_amt2  r3m_avg_bill_amt
# 0             5280.0000         2640.0000
# 1              600.0000          300.0000
# 2            33680.0000        16840.0000
# 3            31089.4668        15544.7334
# 4             9400.0000         4700.0000
# ...                 ...               ...
# 9925          2592.1998         1296.0999
# 9926         27599.3332        13799.6666
# 9927          2792.4000         1396.2000
# 9928          6280.0000         3140.0000
# 9929          4873.8000         2436.9000
#
# [9930 rows x 2 columns]

# %%
data['r3m_avg_bill_amt3'] = data['r3m_avg_bill_amt2'] + data['r3m_avg_bill_amt']
data.head()
# Out:
#    base_ym  dpro_tgt_perd_val  cust_ctg_type cust_class sex_type age  \
# 0   202006           20200630          10001          C        F  28
# 1   202006           20200630          10001          _        _   _
# 2   202006           20200630          10001          E        F  24
# 3   202006           20200630          10001          F        F  32
# 4   202006           20200630          10001          D        M  18
#
#    efct_svc_count dt_stop_yn npay_yn  r3m_avg_bill_amt  r3m_A_avg_arpu_amt  \
# 0               0          N       N         2640.0000           792.00000
# 1               1          N       N          300.0000            90.00000
# 2               1          N       N        16840.0000          2526.00000
# 3               1          N       N        15544.7334          2331.71001
# 4               1          N       N         4700.0000             0.00000
#
#    r3m_B_avg_arpu_amt  r6m_A_avg_arpu_amt  r6m_B_avg_arpu_amt termination_yn  \
# ...

# %%
data.insert(10,'r3m_avg_bill_amt10', data['r3m_avg_bill_amt'] * 10)
data.head()
# Out:
#    base_ym  dpro_tgt_perd_val  cust_ctg_type cust_class sex_type age  \
# 0   202006           20200630          10001          C        F  28
# 1   202006           20200630          10001          _        _   _
# 2   202006           20200630          10001          E        F  24
# 3   202006           20200630          10001          F        F  32
# 4   202006           20200630          10001          D        M  18
#
#    efct_svc_count dt_stop_yn npay_yn  r3m_avg_bill_amt  r3m_avg_bill_amt10  \
# 0               0          N       N         2640.0000           26400.000
# 1               1          N       N          300.0000            3000.000
# 2               1          N       N        16840.0000          168400.000
# 3               1          N       N        15544.7334          155447.334
# 4               1          N       N         4700.0000           47000.000
#
#    r3m_A_avg_arpu_amt  r3m_B_avg_arpu_amt  r6m_A_avg_arpu_amt  \
# ...

# %%
data.drop('r3m_avg_bill_amt10', axis = 1)
# Out:
#       base_ym  dpro_tgt_perd_val  cust_ctg_type cust_class sex_type age  \
# 0      202006           20200630          10001          C        F  28
# 1      202006           20200630          10001          _        _   _
# 2      202006           20200630          10001          E        F  24
# 3      202006           20200630          10001          F        F  32
# 4      202006           20200630          10001          D        M  18
# ...       ...                ...            ...        ...      ...  ..
# 9925   202006           20200630          10001          C        F  15
# 9926   202006           20200630          10001          G        M  12
# 9927   202006           20200630          10005          C        _   _
# 9928   202006           20200630          10001          C        F  40
# 9929   202006           20200630          10001          C        F  59
#
#       efct_svc_count dt_stop_yn npay_yn  r3m_avg_bill_amt  r3m_A_avg_arpu_amt  \
# ...

# %%
data.head()
# Out:
#    base_ym  dpro_tgt_perd_val  cust_ctg_type cust_class sex_type age  \
# 0   202006           20200630          10001          C        F  28
# 1   202006           20200630          10001          _        _   _
# 2   202006           20200630          10001          E        F  24
# 3   202006           20200630          10001          F        F  32
# 4   202006           20200630          10001          D        M  18
#
#    efct_svc_count dt_stop_yn npay_yn  r3m_avg_bill_amt  r3m_avg_bill_amt10  \
# 0               0          N       N         2640.0000           26400.000
# 1               1          N       N          300.0000            3000.000
# 2               1          N       N        16840.0000          168400.000
# 3               1          N       N        15544.7334          155447.334
# 4               1          N       N         4700.0000           47000.000
#
#    r3m_A_avg_arpu_amt  r3m_B_avg_arpu_amt  r6m_A_avg_arpu_amt  \
# ...

# %%
data1 = data.drop('r3m_avg_bill_amt10', axis = 1)

# %%
data1.head()
# Out:
#    base_ym  dpro_tgt_perd_val  cust_ctg_type cust_class sex_type age  \
# 0   202006           20200630          10001          C        F  28
# 1   202006           20200630          10001          _        _   _
# 2   202006           20200630          10001          E        F  24
# 3   202006           20200630          10001          F        F  32
# 4   202006           20200630          10001          D        M  18
#
#    efct_svc_count dt_stop_yn npay_yn  r3m_avg_bill_amt  r3m_A_avg_arpu_amt  \
# 0               0          N       N         2640.0000           792.00000
# 1               1          N       N          300.0000            90.00000
# 2               1          N       N        16840.0000          2526.00000
# 3               1          N       N        15544.7334          2331.71001
# 4               1          N       N         4700.0000             0.00000
#
#    r3m_B_avg_arpu_amt  r6m_A_avg_arpu_amt  r6m_B_avg_arpu_amt termination_yn  \
# ...

# %%
data.sort_index(ascending=False)
# Out:
#       base_ym  dpro_tgt_perd_val  cust_ctg_type cust_class sex_type age  \
# 9929   202006           20200630          10001          C        F  59
# 9928   202006           20200630          10001          C        F  40
# 9927   202006           20200630          10005          C        _   _
# 9926   202006           20200630          10001          G        M  12
# 9925   202006           20200630          10001          C        F  15
# ...       ...                ...            ...        ...      ...  ..
# 4      202006           20200630          10001          D        M  18
# 3      202006           20200630          10001          F        F  32
# 2      202006           20200630          10001          E        F  24
# 1      202006           20200630          10001          _        _   _
# 0      202006           20200630          10001          C        F  28
#
#       efct_svc_count dt_stop_yn npay_yn  r3m_avg_bill_amt  r3m_avg_bill_amt10  \
# ...

# %%
data.sort_index(ascending=True)
# Out:
#       base_ym  dpro_tgt_perd_val  cust_ctg_type cust_class sex_type age  \
# 0      202006           20200630          10001          C        F  28
# 1      202006           20200630          10001          _        _   _
# 2      202006           20200630          10001          E        F  24
# 3      202006           20200630          10001          F        F  32
# 4      202006           20200630          10001          D        M  18
# ...       ...                ...            ...        ...      ...  ..
# 9925   202006           20200630          10001          C        F  15
# 9926   202006           20200630          10001          G        M  12
# 9927   202006           20200630          10005          C        _   _
# 9928   202006           20200630          10001          C        F  40
# 9929   202006           20200630          10001          C        F  59
#
#       efct_svc_count dt_stop_yn npay_yn  r3m_avg_bill_amt  r3m_avg_bill_amt10  \
# ...

# %%
data.sort_values('age',ascending=False)
# Out:
#       base_ym  dpro_tgt_perd_val  cust_ctg_type cust_class sex_type age  \
# 4453   202006           20200630          10010          _        _   _
# 658    202006           20200630          10001          _        _   _
# 5016   202006           20200630          10001          _        _   _
# 8123   202006           20200630          10010          _        _   _
# 9679   202006           20200630          10001          _        _   _
# ...       ...                ...            ...        ...      ...  ..
# 5567   202006           20200630          10001          D        M  10
# 7903   202006           20200630          10001          D        M  10
# 1917   202006           20200630          10001          D        M  10
# 1898   202006           20200630          10001          D        F  10
# 5130   202006           20200630          10001          D        F  10
#
#       efct_svc_count dt_stop_yn npay_yn  r3m_avg_bill_amt  r3m_avg_bill_amt10  \
# ...

# %% [markdown]
# # 3.그룹화

# %%
cust = pd.read_csv('E:/work/ML_prac/Data/sc_cust_info_txn_v1.5.csv')
cust
# Out:
#       base_ym  dpro_tgt_perd_val  cust_ctg_type cust_class sex_type age  \
# 0      202006           20200630          10001          C        F  28
# 1      202006           20200630          10001          _        _   _
# 2      202006           20200630          10001          E        F  24
# 3      202006           20200630          10001          F        F  32
# 4      202006           20200630          10001          D        M  18
# ...       ...                ...            ...        ...      ...  ..
# 9925   202006           20200630          10001          C        F  15
# 9926   202006           20200630          10001          G        M  12
# 9927   202006           20200630          10005          C        _   _
# 9928   202006           20200630          10001          C        F  40
# 9929   202006           20200630          10001          C        F  59
#
#       efct_svc_count dt_stop_yn npay_yn  r3m_avg_bill_amt  r3m_A_avg_arpu_amt  \
# ...

# %% [markdown]
# ### 단일 기준 그룹

# %%
gender_group = cust.groupby('sex_type')
gender_group

# %%
gender_group.count()
# Out:
#           base_ym  dpro_tgt_perd_val  cust_ctg_type  cust_class   age  \
# sex_type
# F            4251               4251           4251        4251  4251
# M            4998               4998           4998        4998  4998
# _             681                681            681         681   681
#
#           efct_svc_count  dt_stop_yn  npay_yn  r3m_avg_bill_amt  \
# sex_type
# F                   4251        4251     4251              4251
# M                   4998        4998     4998              4998
# _                    681         681      681               681
#
#           r3m_A_avg_arpu_amt  r3m_B_avg_arpu_amt  r6m_A_avg_arpu_amt  \
# sex_type
# F                       4251                4251                4251
# M                       4998                4998                4998
# _                        681                 681                 681
#
#           r6m_B_avg_arpu_amt  termination_yn
# sex_type
# F                       4251            4251
# ...

# %%
gender_group.mean(numeric_only=True)
# Out:
#            base_ym  dpro_tgt_perd_val  cust_ctg_type  efct_svc_count  \
# sex_type
# F         202006.0         20200630.0   10001.001882        1.098800
# M         202006.0         20200630.0   10001.004802        1.204882
# _         202006.0         20200630.0   10006.389134        6.462555
#
#           r3m_avg_bill_amt  r3m_A_avg_arpu_amt  r3m_B_avg_arpu_amt  \
# sex_type
# F              9580.926307         1570.372299         5283.876950
# M              9839.707339         1778.988878         5342.748791
# _             40297.790077         4809.827390        21057.412985
#
#           r6m_A_avg_arpu_amt  r6m_B_avg_arpu_amt
# sex_type
# F                 452.780488         4961.455810
# M                 641.426866         4851.027884
# _                4854.788244          864.386867

# %%
gender_group.mean(numeric_only=True)[['r3m_avg_bill_amt','cust_ctg_type']]
# Out:
#           r3m_avg_bill_amt  cust_ctg_type
# sex_type
# F              9580.926307   10001.001882
# M              9839.707339   10001.004802
# _             40297.790077   10006.389134

# %%
gender_group.max(numeric_only=True)[['r3m_avg_bill_amt','cust_ctg_type']]
# Out:
#           r3m_avg_bill_amt  cust_ctg_type
# sex_type
# F             7.979563e+04          10005
# M             1.447397e+05          10005
# _             1.281568e+07          10010

# %% [markdown]
# ### 복수 기준 그룹

# %%
multi_group = cust.groupby(['cust_class', 'sex_type'])

# %%
multi_group.mean(numeric_only=True)[['r3m_avg_bill_amt']]
# Out:
#                      r3m_avg_bill_amt
# cust_class sex_type
# C          F              3804.342244
#            M              3155.385796
#            _              4719.075980
# D          F              7848.842709
#            M              7774.098954
#            _              8419.764574
# E          F             11257.301485
#            M             11158.736812
#            _             12208.980550
# F          F             14913.105272
#            M             15013.379957
#            _             16231.437767
# G          F             16538.595017
#            M             16847.160637
#            _             20180.014811
# H          F             20154.938768
#            M             21052.154088
# _          F              4304.582332
#            M              4728.388010
#            _             65268.733884

# %%
multi_group.max(numeric_only=True)[['r3m_avg_bill_amt']]
# Out:
#                      r3m_avg_bill_amt
# cust_class sex_type
# C          F             6.815017e+04
#            M             2.306917e+04
#            _             2.293453e+04
# D          F             5.407650e+04
#            M             1.447397e+05
#            _             3.232967e+04
# E          F             5.226307e+04
#            M             1.055625e+05
#            _             1.644177e+04
# F          F             5.993527e+04
#            M             7.300037e+04
#            _             2.956300e+04
# G          F             7.979563e+04
#            M             1.129005e+05
#            _             3.589550e+04
# H          F             7.471997e+04
#            M             9.613610e+04
# _          F             3.024210e+04
#            M             1.320952e+05
#            _             1.281568e+07

# %% [markdown]
# # 4.병합

# %% [markdown]
# ### concat

# %%
df1 = pd.DataFrame({'key1' : [0,1,2,3,4], 'value1' : ['a', 'b', 'c','d','e']}, index=[0,1,2,3,4])
df2 = pd.DataFrame({'key1' : [3,4,5,6,7], 'value1' : ['c','d','e','f','g']}, index=[3,4,5,6,7])

# %%
df1
# Out:
#    key1 value1
# 0     0      a
# 1     1      b
# 2     2      c
# 3     3      d
# 4     4      e

# %%
df2
# Out:
#    key1 value1
# 3     3      c
# 4     4      d
# 5     5      e
# 6     6      f
# 7     7      g

# %%
pd.concat([df1,df2])
# Out:
#    key1 value1
# 0     0      a
# 1     1      b
# 2     2      c
# 3     3      d
# 4     4      e
# 3     3      c
# 4     4      d
# 5     5      e
# 6     6      f
# 7     7      g

# %%
pd.concat([df1,df2],axis=1)
# Out:
#    key1 value1  key1 value1
# 0   0.0      a   NaN    NaN
# 1   1.0      b   NaN    NaN
# 2   2.0      c   NaN    NaN
# 3   3.0      d   3.0      c
# 4   4.0      e   4.0      d
# 5   NaN    NaN   5.0      e
# 6   NaN    NaN   6.0      f
# 7   NaN    NaN   7.0      g

# %%
df_concat = pd.concat([df1,df2])
df_concat
# Out:
#    key1 value1
# 0     0      a
# 1     1      b
# 2     2      c
# 3     3      d
# 4     4      e
# 3     3      c
# 4     4      d
# 5     5      e
# 6     6      f
# 7     7      g

# %%
df_concat.reset_index()
# Out:
#    index  key1 value1
# 0      0     0      a
# 1      1     1      b
# 2      2     2      c
# 3      3     3      d
# 4      4     4      e
# 5      3     3      c
# 6      4     4      d
# 7      5     5      e
# 8      6     6      f
# 9      7     7      g

# %%
df_concat.reset_index(drop=True)
# Out:
#    key1 value1
# 0     0      a
# 1     1      b
# 2     2      c
# 3     3      d
# 4     4      e
# 5     3      c
# 6     4      d
# 7     5      e
# 8     6      f
# 9     7      g
